# %%
#!/bin/sh
from ase import Atoms, Atom
from ase.io.trajectory import Trajectory
from ase.lattice import bulk
#from ase.optimize import QuasiNewton
from ase.optimize import BFGS
import numpy as np
from ase.constraints import FixAtoms, FixBondLength
from ase.lattice.surface import fcc111
from ase.visualize import view
from ase.build import fcc111,add_adsorbate,molecule,rotate, fcc211
from sys import path
from ase.io import read,write
from ase.vibrations import Vibrations

import glob

for filename in glob.iglob('traj/ch3oco.*'):
    print(filename)

#for i in species:
#    print(i)

#    file=i
    trajfile="".join((filename))
    
    syst=read(trajfile)
    #view(syst)
    new_filename=filename.replace('.traj','')
    
    
    print(new_filename)
    
    povtop="".join((new_filename, 'top.pov'))
    povside="".join((new_filename, 'side.pov'))

    syst.set_pbc((True,True, True))
    del syst.constraints 


    del syst[0:18]

    rot='-0z, -75x'
    # Common kwargs for eps, png, pov
    kwargs = {
        'rotation'      : rot, # text string with rotation (default='' )
        'radii'         : .85, # float, or a list with one float per atom
      #   'colors'        : None,# List: one (r, g, b) tuple per atom
      'show_unit_cell': 0,   # 0, 1, or 2 to not show, show, and show all of cell
      }

    # Extra kwargs only available for povray (All units in angstrom)
    #kwargs.update({
    #    'run_povray'   : True, # Run povray or just write .pov + .ini files
    #    'display'      : False,# Display while rendering
    #    'pause'        : True, # Pause when done rendering (only if display)
    #    'transparent'  : False,# Transparent background
    #    'canvas_width' : 600, # Width of canvas in pixels
    #    #'canvas_height': 300, # Height of canvas in pixels 
    #    'camera_dist'  : 100.,  # Distance from camera to front atom
    #    'image_plane'  : None, # Distance from front atom to image plane
    #    'camera_type'  : 'perspective', # perspective, ultra_wide_angle
        #   'point_lights' : [],             # [[loc1, color1], [loc2, color2],...]
        #   'area_light'   : [(2., 3., 40.), # location
        #                     'White',       # color
        #                     .7, .7, 3, 3], # width, height, Nlamps_x, Nlamps_y
        #   'background'   : 'White',        # color
        #   'textures'     : None, # Length of atoms list of texture names
        #   'celllinewidth': 0.1,  # Radius of the cylinders representing the cell
    #    })
    
    #write(povtop,syst*(1,1,1), **kwargs)
    
    
    settings=dict(
    transparent=True,  
    canvas_width=600,
    camera_dist=100,  # Distance from camera to front atom
    image_plane=None, # Distance from front atom to image plane
    camera_type='perspective', # perspective, ultra_wide_a
    #Height=300,
    #width=300
    )

    img=write(povtop,syst*(1,1,1), format='pov',**kwargs, povray_settings=settings)

    img.render()
    
    rot='-0z,-90x,-90y'
    # Common kwargs for eps, png, pov
    kwargs = {
        'rotation'      : rot, # text string with rotation (default='' )
        'radii'         : .85, # float, or a list with one float per atom
        #   'colors'        : None,# List: one (r, g, b) tuple per atom
        'show_unit_cell': 0,   # 0, 1, or 2 to not show, show, and show all of cell
        }
    
    # # Extra kwargs only available for povray (All units in angstrom)
    # kwargs.update({
    #     'run_povray'   : True, # Run povray or just write .pov + .ini files
    #     'display'      : False,# Display while rendering
    #     'pause'        : True, # Pause when done rendering (only if display)
    #     'transparent'  : False,# Transparent background
    #     'canvas_width' : 600, # Width of canvas in pixels
    #     #'canvas_height': 300, # Height of canvas in pixels 
    #     'camera_dist'  : 100.,  # Distance from camera to front atom
    #     'image_plane'  : None, # Distance from front atom to image plane
    #     'camera_type'  : 'perspective', # perspective, ultra_wide_angle
    #     #   'point_lights' : [],             # [[loc1, color1], [loc2, color2],...]
    #     #   'area_light'   : [(2., 3., 40.), # location
    #     #                     'White',       # color
    #     #                     .7, .7, 3, 3], # width, height, Nlamps_x, Nlamps_y
    #     #   'background'   : 'White',        # color
    #     #   'textures'     : None, # Length of atoms list of texture names
    #     #   'celllinewidth': 0.1,  # Radius of the cylinders representing the cell
    #     })
    
    # write(povside,syst*(1,1,1), **kwargs)
    
    settings=dict(
    transparent=True,  
    canvas_width=600,
    camera_dist=100,  # Distance from camera to front atom
    image_plane=None, # Distance from front atom to image plane
    camera_type='perspective', # perspective, ultra_wide_a
    #Height=300,
    #width=300
    )

    img=write(povside,syst*(1,1,1), format='pov',**kwargs, povray_settings=settings)

    img.render()
# Out:
# traj/ch3oco.traj
# traj/ch3oco
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_3929/3093141441.py in <module>
#      85     img=write(povtop,syst*(1,1,1), format='pov',**kwargs, povray_settings=settings)
#      86
# ---> 87     img.render()
#      88
#      89     rot='-0z,-90x,-90y'
#
# ~/.local/lib/python3.7/site-packages/ase/io/pov.py in render(self, povray_executable, stderr, clean_up)
#     566         cmd = [povray_executable, str(self.path)]
#     567
# --> 568         check_call(cmd, stderr=stderr)
#     569         png_path = self.path.with_suffix('.png').absolute()
#     570         if not png_path.is_file():
#
# ~/anaconda3/envs/rmg_env/lib/python3.7/subprocess.py in check_call(*popenargs, **kwargs)
#     361         if cmd is None:
#     362             cmd = popenargs[0]
# --> 363         raise CalledProcessError(retcode, cmd)
#     364     return 0
#     365
#
# CalledProcessError: Command '['povray', 'traj/ch3ocotop.ini']' returned non-zero exit status 1.

# %%
#!/bin/sh
from ase import Atoms, Atom
from ase.io.trajectory import Trajectory
from ase.lattice import bulk
#from ase.optimize import QuasiNewton
from ase.optimize import BFGS
import numpy as np
from ase.constraints import FixAtoms, FixBondLength
from ase.lattice.surface import fcc111
from ase.visualize import view
from ase.build import fcc111,add_adsorbate,molecule,rotate, fcc211
from sys import path
from ase.io import read,write
from ase.vibrations import Vibrations

import glob

filename="c2h4-mod.traj"

trajfile="".join((filename))
    
syst=read(trajfile)
    
new_filename=filename.replace('.traj','')
    
view(syst)    
print(new_filename)
    
povtop="".join((new_filename, 'top.pov'))
povside="".join((new_filename, 'side.pov'))

syst.set_pbc((True,True, True))
del syst.constraints 

b=[0,1,2,15,16,17,18,19,20]

del syst[b]

rot='-0z, -75x'
    # Common kwargs for eps, png, pov
kwargs = {
        'rotation'      : rot, # text string with rotation (default='' )
        'radii'         : .85, # float, or a list with one float per atom
      #   'colors'        : None,# List: one (r, g, b) tuple per atom
      'show_unit_cell': 0,   # 0, 1, or 2 to not show, show, and show all of cell
      }

settings=dict(
    transparent=True,  
    canvas_width=600,
    camera_dist=100,  # Distance from camera to front atom
    image_plane=None, # Distance from front atom to image plane
    camera_type='perspective', # perspective, ultra_wide_a
    #Height=300,
    #width=300
    )

img=write(povtop,syst*(1,1,1), format='pov',**kwargs, povray_settings=settings)

img.render()
# Out:
# c2h4-mod
# PosixPath('/home/bkr/CBH-thermo/slab_images/c2h4-modtop.png')

# %%
syst=read('c2h4-mod.traj')
syst.set_cell([0,0,0])
syst.center(vacuum=10,axis=2)
view(syst)
