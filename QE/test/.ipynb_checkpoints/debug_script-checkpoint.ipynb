# %%
import numpy as np
import pandas as pd

Name='surfaceThermoPt111_QE'
N_BEE=1

label=[]
index=[]

for k in range(N_BEE):
    file="".join((Name,"_",str(k),".py"))
    original_file="".join((Name,".py"))
    s=open(original_file,'r')
    new_file_content=""    


    for line in s:
        if line.startswith("    label"):
            old=line.strip()
            bits=line.split(" = ")
            label.append(bits[1].replace(",","").replace("\n","").replace('"',""))
            
            
        if line.startswith("    index"):
            old=line.strip()
            bits=line.split(" = ")
            index.append(int(bits[1].replace(",","")))
            new_line=line.replace(old,old)
            new_file_content += new_line  
        else:
            old=line.strip()
            new_line=line.replace(old,old)
            new_file_content += new_line  
            
    writing_file = open(file, "w")
    writing_file.write(new_file_content)
    writing_file.close()
    
    #The number of possible entries to modify is given by the number of collected labels
    no=len(label)    
    print(no)
    for i in range(1,no): #
        print(i)
        print(label[i])
        #print(index[i])
        #filename="".join((label[i],'_bee.txt'))
        #filename='ensembles/' + str(label[i]) + '_bee.txt'
        #data=pd.read_csv(filename, sep="\t", header=0)
        #perturbation=data.iloc[k,3]     
        
        s=open(file,'r')
        new_file_content="" 
        idx="".join(("    index = ",str(index[i]),","))
        #When we look for the last script, we have to adjust the index since there is no i+1 for the switch. 
        if i==no-1:
            idx_next="".join(("    index = ",str(index[-1]+1),","))
        else:    
            idx_next="".join(("    index = ",str(index[i+1]),","))
        flag=False
        for line in s: 
             if idx in line:
                 flag=True
                 old=line.strip()
                 new_line=line.replace(old,old)
                 new_file_content += new_line 
                 for line in s:
                     check=line.strip()
                     if check.startswith("NASAPolynomial(coeffs=[") and flag:
                         old=line.strip()
                         bits=line.split("[")
                         thermo=bits[1].split("]")
                         polynom=thermo[0].split(",")
                         initial_H=float(polynom[5])
                         
                         #No nitrogen chemistry at the moment
                         if 'N' not in label[i]:
                             filename='ensembles/' + str(label[i]) + '_bee.txt'
                             data=pd.read_csv(filename, sep="\t", header=0)
                             perturbation=data.iloc[k,3]  
                             print(label[i])
                             changed_H=initial_H+float(perturbation)/8.314e-3                             
                         else:
                             changed_H=initial_H
                             #print(label[i])
                         end=thermo[1].replace("\n","")
                         #print(initial_H*8.314e-3,changed_H, changed_H-initial_H*8.314e-3)
                         #print(initial_H,changed_H)
                         #Restore the polynomial first
                         modified="".join((polynom[0],",",polynom[1],",",polynom[2],",",polynom[3],",",polynom[4]," ,",str(changed_H),",",polynom[6]))
                         add_more="".join(("NASAPolynomial(coeffs=[", modified,"]", end))
                         new_line=line.replace(old,add_more)
                         new_file_content +=new_line
                     elif idx_next in line:
                         flag=False  
                         old=line.strip()
                         new_line=line.replace(old,old)
                         new_file_content += new_line  
                     else:
                         old=line.strip()
                         new_line=line.replace(old,old)
                         new_file_content += new_line    

             else:
                 old=line.strip()
                 new_line=line.replace(old,old)
                 new_file_content += new_line                  
               
        s.close()
        writing_file = open(file, "w")
        writing_file.write(new_file_content)
        writing_file.close()
# Out:
# 113
# 1
# H_ads
# H_ads
# H_ads
# 2
# H2_ads
# H2_ads
# H2_ads
# 3
# H2O_ads
# H2O_ads
# H2O_ads
# 4
# OH_ads
# OH_ads
# OH_ads
# 5
# HOOH_ads
# HOOH_ads
# HOOH_ads
# 6
# O2-bi_ads
# O2-bi_ads
# O2-bi_ads
# 7
# OOH_ads
# OOH_ads
# OOH_ads
# 8
# O_ads
# O_ads
# O_ads
# 9
# OCH3_ads
# OCH3_ads
# OCH3_ads
# 10
# C_ads
# C_ads
# C_ads
# 11
# CC_ads
# CC_ads
# CC_ads
# 12
# CCH2_ads
# CCH2_ads
# CCH2_ads
# 13
# CCH3_ads
# CCH3_ads
# CCH3_ads
# 14
# CH_ads
# CH_ads
# CH_ads
# 15
# CHCH-bi_ads
# CHCH-bi_ads
# CHCH-bi_ads
# 16
# CHCH-vdw_ads
# CHCH-vdw_ads
# CHCH-vdw_ads
# 17
# CH2_ads
# CH2_ads
# CH2_ads
# 18
# CH2CH2-bi_ads
# CH2CH2-bi_ads
# CH2CH2-bi_ads
# 19
# CH3_ads
# CH3_ads
# CH3_ads
# 20
# CH3CH3_ads
# CH3CH3_ads
# CH3CH3_ads
# 21
# CH4_ads
# CH4_ads
# CH4_ads
# 22
# CO_ads
# CO_ads
# CO_ads
# 23
# COH_ads
# COH_ads
# COH_ads
# 24
# CHCH2-bi_ads
# CHCH2-bi_ads
# CHCH2-bi_ads
# 25
# CH2CH3_ads
# CH2CH3_ads
# CH2CH3_ads
# 26
# H2CO_ads
# H2CO_ads
# H2CO_ads
# 27
# H2COH_ads
# H2COH_ads
# H2COH_ads
# 28
# CH3OH_ads
# CH3OH_ads
# CH3OH_ads
# 29
# CHC-bi_ads
# CHC-bi_ads
# CHC-bi_ads
# 30
# CHCH2_ads
# CHCH2_ads
# CHCH2_ads
# 31
# CHCH3_ads
# CHCH3_ads
# CHCH3_ads
# 32
# HCO_ads
# HCO_ads
# HCO_ads
# 33
# HCO-bi_ads
# HCO-bi_ads
# HCO-bi_ads
# 34
# HCOH_ads
# HCOH_ads
# HCOH_ads
# 35
# H2CO-bi_ads
# H2CO-bi_ads
# H2CO-bi_ads
# 36
# COOH_ads
# COOH_ads
# COOH_ads
# 37
# CO2_ads
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3701/2476044065.py in <module>
#      71                          thermo=bits[1].split("]")
#      72                          polynom=thermo[0].split(",")
# ---> 73                          initial_H=float(polynom[5])
#      74
#      75                          #No nitrogen chemistry at the moment
#
# IndexError: list index out of range
